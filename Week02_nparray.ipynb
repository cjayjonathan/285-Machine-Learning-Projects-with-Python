# %% [markdown]
# <a href="https://colab.research.google.com/github/cjayjonathan/285-Machine-Learning-Projects-with-Python/blob/main/Week02_nparray.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 2: Creating NumPy Arrays

# %%
import numpy as np

import matplotlib.pyplot as pp

# %%
lines = open('/content/Week02_monalisa.txt', 'r').readlines()

# %%
lines[0]
# Out:
# '107 93 104 83 91 66 70 77 62 91 89 74 90 68 65 101 93 74 68 77 73 75 77 85 77 71 82 80 74 69 56 50 53 74 63 54 63 88 103 74 67 73 85 72 75 81 107 69 63 73 72 90 89 97 78 74 92 83 92 85 93 92 66 79 73 77 85 100 83 86 84 80 74 78 86 77 66 68 65 68 63 71 90 76 67 50 37 41 51 46 61 82 61 62 58 79 60 49 59 59 70 69 72 67 95 77 70 72 70 65 91 70 64 78 74 61 56 75 51 59 100 95 65 46 49 75 65 91 85 87 88 87 78 95\n'

# %%
len(lines)
# Out:
# 200

# %%
monalisa_bw = np.loadtxt('/content/Week02_monalisa.txt')

# %%
monalisa_bw
# Out:
# array([[107.,  93., 104., ...,  87.,  78.,  95.],
#        [ 72.,  96.,  99., ...,  68.,  95.,  73.],
#        [ 98., 117., 105., ...,  73., 104.,  86.],
#        ...,
#        [ 36.,  12.,  28., ...,  20.,  23.,  16.],
#        [ 68.,  41.,  19., ...,  22.,   7.,  18.],
#        [117.,  17.,   9., ...,  42.,  37.,  68.]])

# %%
monalisa_bw.ndim
# Out:
# 2

# %%
monalisa_bw.shape
# Out:
# (200, 134)

# %%
monalisa_bw.size
# Out:
# 26800

# %%
monalisa_bw.dtype
# Out:
# dtype('float64')

# %%
pp.imshow(monalisa_bw)

# %%
pp.imshow(monalisa_bw, cmap='gray')

# %%
monalisa = np.load('/content/Week02_monalisa.npy')

# %%
monalisa.shape
# Out:
# (1198, 804, 3)

# %%
pp.figure(figsize=(5,8))  # later
pp.imshow(monalisa)

# %%
monalisa[600,400,0]
# Out:
# np.uint8(247)

# %%
monalisa[-50,-50,1]
# Out:
# np.uint8(11)

# %%
pp.imshow(monalisa[400:800,200:600,0:3])
#pp.imshow(monalisa[400:800,200:600,0:1])

# %%
pp.imshow(monalisa[400:800,:,:])

# %%
pp.plot(monalisa[20,::20,0])

# %%
rand_2d = np.random.random(size=(8,8))

# %%
rand_2d
# Out:
# array([[0.88714141, 0.3061462 , 0.28877028, 0.86917901, 0.10257134,
#         0.96343707, 0.40841211, 0.60882706],
#        [0.81230251, 0.33813495, 0.21674268, 0.97541184, 0.10238097,
#         0.73619726, 0.76363094, 0.55342071],
#        [0.66578338, 0.14808059, 0.59412656, 0.04070888, 0.96414445,
#         0.2474629 , 0.12712988, 0.17544999],
#        [0.12367385, 0.20457889, 0.64663186, 0.97264809, 0.43672656,
#         0.36365713, 0.99682376, 0.43109541],
#        [0.36907673, 0.22398839, 0.08288311, 0.87021294, 0.35205304,
#         0.09080569, 0.90395038, 0.88149393],
#        [0.55418577, 0.93123306, 0.51688463, 0.69364599, 0.13332941,
#         0.10350318, 0.53491191, 0.95888848],
#        [0.27762786, 0.58917137, 0.95097361, 0.09414665, 0.87636018,
#         0.52062257, 0.48844484, 0.55647602],
#        [0.03460792, 0.53601972, 0.21630412, 0.24579956, 0.47753115,
#         0.59256068, 0.36567532, 0.94798333]])

# %%
pp.matshow(rand_2d)

# %%
np.save('random.npy', rand_2d)

# %%
np.savetxt('random.txt', rand_2d)

# %%
open('random.txt', 'r').readlines()
# Out:
# ['8.871414115932252376e-01 3.061462038425515342e-01 2.887702830965507284e-01 8.691790114082178498e-01 1.025713444669315022e-01 9.634370737833141130e-01 4.084121069118761271e-01 6.088270619919119442e-01\n',
#  '8.123025070567679862e-01 3.381349511296374288e-01 2.167426832917251911e-01 9.754118444523617315e-01 1.023809728566051902e-01 7.361972638175433570e-01 7.636309365706647201e-01 5.534207086505904538e-01\n',
#  '6.657833840028613004e-01 1.480805861942877666e-01 5.941265621386960794e-01 4.070887530998168469e-02 9.641444535210290656e-01 2.474628969002291567e-01 1.271298791255498495e-01 1.754499895278219812e-01\n',
#  '1.236738490562755421e-01 2.045788914164519134e-01 6.466318641596012773e-01 9.726480885967880852e-01 4.367265618822911977e-01 3.636571341729460949e-01 9.968237565078734708e-01 4.310954135267509590e-01\n',
# ...
